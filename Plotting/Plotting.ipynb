# %% [markdown]
# # **Plotting**

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 72634, done.
# remote: Counting objects: 100% (70142/70142), done.
# remote: Compressing objects: 100% (70125/70125), done.
# remote: Total 72634 (delta 52), reused 70068 (delta 14), pack-reused 2492
# Receiving objects: 100% (72634/72634), 121.90 MiB | 30.63 MiB/s, done.
# Resolving deltas: 100% (113/113), done.
# Checking out files: 100% (3008/3008), done.

# %% [markdown]
# # General plot.**py**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x = np.random.random((10, 1))

print(x)
# Out:
# [[0.23093571]
#  [0.53370811]
#  [0.30042105]
#  [0.74131129]
#  [0.84654889]
#  [0.36202495]
#  [0.75510821]
#  [0.49817665]
#  [0.17244009]
#  [0.38443863]]

# %%
plt.plot(x, '*-')
plt.show()

# %%
x = np.linspace(0, 100, 50)
y = np.power(x, .5)
plt.plot(x, y, '+-')
plt.show()

# %%
sns.set()
sns.lineplot(x, y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Plotting Data from Dataset**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('machine_learning/Machine_learning/3_Mobile_dataset/mobile_cleaned.csv')
data.head()
# Out:
#    0  12  55    155  250  1.3  10.5  5     2  0.1  ...  4  2.1  3.3  67.8  64  \
# 0  0   1  55  132.0  300  1.3  10.6  5  0.30    1  ...  4    4    6  64.0  32
# 1  0   9  55  142.0  329  1.5   8.5  5  2.00    3  ...  4    9    6  72.0  32
# 2  0   8  55  152.0  385  1.3   8.0  5  2.00    3  ...  4    1    3  75.1  32
# 3  1   1  55  234.0  385  1.3   7.9  5  1.92    3  ...  4    1    6  91.0  32
# 4  0  14  55  179.0  280  1.3   7.9  5  5.00    3  ...  4    7    3  71.0  32
#
#    5.2  3.4  2000  125  1.2
# 0    5    3  2000  165    1
# 1    6    3  2500  164    0
# 2    6    3  3000  165    1
# 3    6    3  3000  165    0
# 4    6    3  2900  165    0
#
# [5 rows x 40 columns]

# %%
data.describe()
# Out:
#                 0          12          55         155          250  \
# count  108.000000  108.000000  108.000000  108.000000   108.000000
# mean     0.990741    7.694444   29.759259  154.352778   406.092593
# std      1.349942    3.190108   15.178607   22.498650   176.627097
# min      0.000000    0.000000    3.000000   97.000000   160.000000
# 25%      0.000000    7.750000   16.000000  139.500000   264.750000
# 50%      0.000000    8.000000   29.000000  152.000000   360.000000
# 75%      3.000000   10.000000   41.000000  169.000000   501.000000
# max      4.000000   14.000000   56.000000  234.000000  1093.000000
#
#               1.3        10.5           5           2         0.1  ...  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000  ...
# mean     1.636481    8.310185    3.833333    4.866852    2.981481  ...
# std      0.387224    1.160321    1.585566    2.575408    0.305142  ...
# min      1.000000    5.100000    0.000000    0.300000    1.000000  ...
# 25%      1.300000    7.600000    2.000000    4.000000    3.000000  ...
# 50%      1.600000    8.050000    5.000000    5.000000    3.000000  ...
# 75%      1.800000    8.900000    5.000000    5.000000    3.000000  ...
# max      2.700000   11.600000    7.000000   16.000000    4.000000  ...
#
#                 4         2.1         3.3        67.8           64  \
# count  108.000000  108.000000  108.000000  108.000000   108.000000
# mean     3.537037   14.861111    4.925926   74.321296   104.888889
# std      1.443166    7.904167    1.705975    7.920777   277.057615
# min      0.000000    0.000000    0.000000   58.600000     0.000000
# 25%      3.000000    9.000000    3.000000   70.975000     0.000000
# 50%      4.000000   14.500000    6.000000   73.850000    32.000000
# 75%      4.000000   20.000000    6.000000   76.775000   128.000000
# max      6.000000   34.000000    7.000000  136.500000  2048.000000
#
#               5.2         3.4         2000         125         1.2
# count  108.000000  108.000000   108.000000  108.000000  108.000000
# mean     6.092593    4.388889  2849.574074   50.101852    0.842593
# std      2.556052    3.158828   652.959520   49.202032    0.365882
# min      0.000000    0.000000  1560.000000    1.000000    0.000000
# 25%      5.000000    3.000000  2492.500000   12.000000    1.000000
# 50%      6.000000    3.000000  2900.000000   21.000000    1.000000
# 75%      6.000000    4.000000  3100.000000   92.000000    1.000000
# max     14.000000   14.000000  5000.000000  166.000000    1.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# # Uni-Variant

# %%
sns.countplot(x ='sim_type', data = data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6ff9ae3e3c12> in <module>()
# ----> 1 sns.countplot(x ='sim_type', data = data)
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'sim_type'

# %%
sns.distplot(data["stand_by_time"])
plt.show()

# %%
sns.histplot(data=data, x="stand_by_time")
plt.show()

# %% [markdown]
# # Bi-Variant

# %%
ax = sns.scatterplot(x="stand_by_time", y="battery_capacity", data=data)
plt.show()

# %%
#Minimum, 25,50,75, max
ax = sns.boxplot(x="is_liked", y="battery_capacity", data=data)
plt.show()
#Minimum = Q1–1.5 * IQR and Maximum = Q3 + 1.5 * IQR

# %%
ax = sns.boxplot(x = "expandable_memory", y = "price", data=data)
plt.show()

# %% [markdown]
# # Multi-Variant

# %%
ax = sns.violinplot(x='expandable_memory', y='price', data=data,
               hue='is_liked', split=True)
plt.show()

# %%
ax = sns.scatterplot(x = "stand_by_time", y = "battery_capacity", hue="thickness", data=data)
plt.show()

# %%
dataframe = pd.read_csv("EDA/iris.csv")
print(dataframe.head())


ax = sns.scatterplot(x="petal.length", y="petal.width",hue="variety",size = "sepal.width",data=dataframe)
plt.show()

# %%
ax = sns.swarmplot(x='sepal.length', y='variety', data=dataframe)

# %%
sns.pairplot(dataframe[['petal.length','petal.width','sepal.length','sepal.width']])
plt.show()

# %%
sns.pairplot(dataframe, hue='variety')
plt.show()
